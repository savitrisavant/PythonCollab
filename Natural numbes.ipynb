# %% [markdown]
# <a href="https://colab.research.google.com/github/savitrisavant/PythonCollab/blob/main/Natural%20numbes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
n=int(input("enter a number:"))
for i in range (1,n+1):
 print(i)
# Out:
# enter a number:5
# 1
# 2
# 3
# 4
# 5
